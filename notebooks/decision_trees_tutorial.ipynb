# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier

# %%
data=pd.read_csv('./train_data_tree.csv')

# %%
y=data['num']
x=data[['sex','exang']]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
clf=DecisionTreeClassifier()
clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
clf.score(x_test,y_test)
# Out:
# 0.7

# %%
from sklearn.tree import plot_tree
plot_tree(clf,feature_names=['sex','exang'],filled=True)
# Out:
# [Text(0.5, 0.8333333333333334, 'exang <= 0.5\ngini = 0.498\nsamples = 178\nvalue = [94, 84]'),
#  Text(0.25, 0.5, 'sex <= 0.5\ngini = 0.436\nsamples = 115\nvalue = [78, 37]'),
#  Text(0.125, 0.16666666666666666, 'gini = 0.307\nsamples = 37\nvalue = [30, 7]'),
#  Text(0.375, 0.16666666666666666, 'gini = 0.473\nsamples = 78\nvalue = [48, 30]'),
#  Text(0.75, 0.5, 'sex <= 0.5\ngini = 0.379\nsamples = 63\nvalue = [16, 47]'),
#  Text(0.625, 0.16666666666666666, 'gini = 0.486\nsamples = 12\nvalue = [5, 7]'),
#  Text(0.875, 0.16666666666666666, 'gini = 0.338\nsamples = 51\nvalue = [11, 40]')]

# %%
l_node=0
N=clf.tree_.n_node_samples[l_node]
e0=clf.tree_.impurity[l_node]

# %%
l_node=clf.tree_.children_left[0]
n1=clf.tree_.n_node_samples[l_node]
e1=clf.tree_.impurity[l_node]

# %%
r_node=clf.tree_.children_right[0]
n2=clf.tree_.n_node_samples[r_node]
e2=clf.tree_.impurity[r_node]

# %%
IG=e0-((n1/N)*e1+(n2/N)*e2)
IG
# Out:
# 0.08233022979075022

# %%
l_node
# Out:
# 1
